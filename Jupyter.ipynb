# %%
# Caso 1: Impresión básica con comillas (¡Este ya lo tienes!)
print("Hola, este es mi primer apunte en Jupyter.")
print('Las comillas simples también funcionan perfectamente.')

# Caso 2: Imprimir variables y texto combinados
edad = 18
print("Tengo", edad, "años y estoy aprendiendo a programar.")

# Caso 3: Uso de f-strings (cadenas formateadas) para inyectar variables
nombre = "Sebastián"
print(f"Hola, me llamo {nombre}. Las f-strings son muy útiles.")

# Caso 4: Modificar el separador y el final de línea
# 'sep' cambia el espacio por defecto entre palabras, y 'end' evita el salto de línea.
print("Python", "es", "genial", sep="-")
print("Esta línea no hace un salto hacia abajo...", end=" ")
print("y esta otra continúa justo al lado.")
# Out:
# Hola, este es mi primer apunte en Jupyter.
# Las comillas simples también funcionan perfectamente.
# Tengo 18 años y estoy aprendiendo a programar.
# Hola, me llamo Sebastián. Las f-strings son muy útiles.
# Python-es-genial
# Esta línea no hace un salto hacia abajo... y esta otra continúa justo al lado.

# %% [markdown]
# # Explorando la función print() en Python
# La función `print()` es una instrucción integrada (built-in) de Python que envía texto, variables u otros objetos a la consola (salida estándar).
#
# ## 1. Impresión básica y uso de comillas
# En Python, podemos usar comillas simples o dobles indistintamente para imprimir cadenas de texto (strings).
